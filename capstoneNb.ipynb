# %%
spark.conf.set("fs.azure.account.auth.type", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.capstonebrillio.dfs.core.windows.net", "da25c085-97e4-48a6-9ab0-7d40f0d6aee2")
spark.conf.set("fs.azure.account.oauth2.client.secret.capstonebrillio.dfs.core.windows.net", "hzH7Q~al344Xh.P5HIweKtYeZwR30rh5O63Uw")
spark.conf.set("fs.azure.account.oauth2.client.endpoint.capstonebrillio.dfs.core.windows.net", "https://login.microsoftonline.com/2b02a57b-28d7-425c-88af-b52b3df9a6d7/oauth2/token")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfAthletes = spark.read.format("csv").option("header","true").load("abfss://capstonedata@capstonebrillio.dfs.core.windows.net/Athletes.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfAthletes.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+-------------------+
#                 Name|                 NOC|         Discipline|
# +--------------------+--------------------+-------------------+
#      AALERUD Katrine|                null|       Cycling Road|
#          ABAD Nestor|               Spain|Artistic Gymnastics|
#    ABAGNALE Giovanni|               Italy|             Rowing|
#       ABALDE Alberto|               Spain|         Basketball|
#        ABALDE Tamara|               Spain|         Basketball|
#            ABALO Luc|              France|           Handball|
#         ABAROA Cesar|               Chile|             Rowing|
#        ABASS Abobakr|               Sudan|           Swimming|
#     ABBASALI Hamideh|Islamic Republic ...|             Karate|
#        ABBASOV Islam|          Azerbaijan|          Wrestling|
#         ABBINGH Lois|         Netherlands|           Handball|
#          ABBOT Emily|           Australia|Rhythmic Gymnastics|
#        ABBOTT Monica|United States of ...|  Baseball/Softball|
# ABDALLA Abubaker ...|               Qatar|          Athletics|
#       ABDALLA Maryam|               Egypt|  Artistic Swimming|
#       ABDALLAH Shahd|               Egypt|  Artistic Swimming|
#  ABDALRASOOL Mohamed|               Sudan|               Judo|
#    ABDEL LATIF Radwa|               Egypt|           Shooting|
#     ABDEL RAZEK Samy|               Egypt|           Shooting|
#    ABDELAZIZ Abdalla|               Egypt|             Karate|
# +--------------------+--------------------+-------------------+
# only showing top 20 rows
#
# </div>

# %%
dfMedals = spark.read.format("csv").option("header","true").load("abfss://capstonedata@capstonebrillio.dfs.core.windows.net/Medals.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfMedals.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------------+----+------+------+-----+-------------+----+
# Rank|            Team/NOC|Gold|Silver|Bronze|Total|Rank by Total| _c7|
# +----+--------------------+----+------+------+-----+-------------+----+
#    1|United States of ...|  39|    41|    33|  113|            1|null|
#    2|People&#39;s Republic...|  38|    32|    18|   88|            2|null|
#    3|               Japan|  27|    14|    17|   58|            5|null|
#    4|       Great Britain|  22|    21|    22|   65|            4|null|
#    5|                ROCC|  20|    28|  null|   71|            3|null|
#    6|           Australia|  17|     7|    22|   46|            6|null|
#    7|         Netherlands|  10|    12|    14|   36|            9|null|
#    8|               Franc|  10|    12|    11|   33|           10|null|
#    9|             Germany|  10|    11|    16|   37|            8|  12|
#   10|             Italy!!|  10|    10|    20|   40|         null|null|
#   11|              Canada|   7|     6|    11|   24|           11|null|
#   12|              Brazil|   7|     6|     8|   21|           12|null|
#   13|         New Zealand|   7|     6|     7|   20|           13|null|
#   14|               Cubaa|   7|     3|  null|   15|           18|null|
#   15|             Hungary|   6|     7|     7|   20|           13|null|
#   16|   Republic of Korea|   6|     4|    10|   20|         null|null|
#   17|              Poland|   4|     5|     5|   14|           19|null|
#   18|      Czech Republic|   4|     4|     3|   11|           23|null|
#   19|               Kenya|   4|     4|     2|   10|           25|null|
#   20|              Norway|   4|     2|     2|    8|           29|null|
# +----+--------------------+----+------+------+-----+-------------+----+
# only showing top 20 rows
#
# </div>

# %%
dfTeams = spark.read.format("csv").option("header","true").load("abfss://capstonedata@capstonebrillio.dfs.core.windows.net/Teams.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfTeams.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+--------------+--------------------+--------------------+----------+
#          Name|    Discipline|                 NOC|               Event|       _c4|
# +-------------+--------------+--------------------+--------------------+----------+
#       Belgium|3x3 Basketball|             Belgium|                 Men|      null|
#         China|3x3 Basketball|People&#39;s Republic...|                 Men|      null|
#         China|3x3 Basketball|People&#39;s Republic...|               Women|      null|
#        France|3x3 Basketball|              France|               Women|      null|
#         Italy|3x3 Basketball|               Italy|               Women|      null|
#         Japan|          null|               Japan|                 Men|      null|
#         Japan|3x3 Basketball|               Japan|               Women|      null|
#        Latvia|3x3 Basketball|              Latvia|                 Men|      null|
#      Mongolia|3x3 Basketball|            Mongolia|               Women|     Women|
#   Netherlands|3x3 Basketball|         Netherlands|                 Men|      null|
#        Poland|3x3 Basketball|              Poland|                 Men|      null|
#           ROC|3x3 Basketball|                 ROC|                 Men|      null|
#           ROC|3x3 Basketball|                 ROC|               Women|      null|
#       Romania|3x3 Basketball|                null|               Women|      null|
#        Serbia|3x3 Basketball|              Serbia|                 Men|      null|
#     Lithuania|      Swimming|           Lithuania|Men&#39;s 4 x 100m Me...|      null|
# United States|3x3 Basketball|United States of ...|               Women|      null|
#     Australia|       Archery|           Australia|          Men&#39;s Team|Men&#39;s Team|
#     Australia|       Archery|           Australia|          Mixed Team|      null|
#    Bangladesh|       Archery|          Bangladesh|          Mixed Team|      null|
# +-------------+--------------+--------------------+--------------------+----------+
# only showing top 20 rows
#
# </div>

# %%
for x in dfMedals.columns:
    if "_c" in x:
        dfMedals=dfMedals.drop(x)
#fixneeded
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfMedals.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------------+----+------+------+-----+-------------+
# Rank|            Team/NOC|Gold|Silver|Bronze|Total|Rank by Total|
# +----+--------------------+----+------+------+-----+-------------+
#    1|United States of ...|  39|    41|    33|  113|            1|
#    2|People&#39;s Republic...|  38|    32|    18|   88|            2|
#    3|               Japan|  27|    14|    17|   58|            5|
#    4|       Great Britain|  22|    21|    22|   65|            4|
#    5|                ROCC|  20|    28|  null|   71|            3|
#    6|           Australia|  17|     7|    22|   46|            6|
#    7|         Netherlands|  10|    12|    14|   36|            9|
#    8|               Franc|  10|    12|    11|   33|           10|
#    9|             Germany|  10|    11|    16|   37|            8|
#   10|             Italy!!|  10|    10|    20|   40|         null|
#   11|              Canada|   7|     6|    11|   24|           11|
#   12|              Brazil|   7|     6|     8|   21|           12|
#   13|         New Zealand|   7|     6|     7|   20|           13|
#   14|               Cubaa|   7|     3|  null|   15|           18|
#   15|             Hungary|   6|     7|     7|   20|           13|
#   16|   Republic of Korea|   6|     4|    10|   20|         null|
#   17|              Poland|   4|     5|     5|   14|           19|
#   18|      Czech Republic|   4|     4|     3|   11|           23|
#   19|               Kenya|   4|     4|     2|   10|           25|
#   20|              Norway|   4|     2|     2|    8|           29|
# +----+--------------------+----+------+------+-----+-------------+
# only showing top 20 rows
#
# </div>

# %%
import pyspark.sql.functions as f
from functools import reduce

dfnullmedal=dfMedals.where(reduce(lambda x, y: x | y, (f.col(x).isNull() | (f.col(x)=="null") for x in dfMedals.columns)))
# Reduce-> implementing function across a sequence and in this case funct would be returning true if any of the value in the sequence is true which means atleast one of the column value is null
dfnullmedal.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----------------+----+------+------+-----+-------------+
# Rank|         Team/NOC|Gold|Silver|Bronze|Total|Rank by Total|
# +----+-----------------+----+------+------+-----+-------------+
#    5|             ROCC|  20|    28|  null|   71|            3|
#   10|          Italy!!|  10|    10|    20|   40|         null|
#   14|            Cubaa|   7|     3|  null|   15|           18|
#   16|Republic of Korea|   6|     4|    10|   20|         null|
#   22|           SpainZ|   3|     8|  null|   17|           17|
#   29|          Belgium|null|     1|     3|    7|           33|
#   39|          Ireland|   2|     0|  null|    4|           47|
#   52|     South Africa|   1|     2|  null|    3|           60|
#   77|          Namibia|   0|     1|  null|    1|           77|
#   77|    Tturkmenistan|   0|     1|     0|    1|         null|
#   86|          Grenada|null|     0|     1|    1|           77|
# +----+-----------------+----+------+------+-----+-------------+
#
# </div>

# %%
dfnullathlete=dfAthletes.where(reduce(lambda x, y: x | y, (f.col(x).isNull() | (f.col(x)=="null") for x in dfAthletes.columns)))
# Reduce-> implementing function across a sequence and in this case funct would be returning true if any of the value in the sequence is true which means atleast one of the column value is null
dfnullathlete.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+------------+
#                 Name|                 NOC|  Discipline|
# +--------------------+--------------------+------------+
#      AALERUD Katrine|                null|Cycling Road|
#      ABDELAZIZ Farah|               Egypt|        null|
#      AGGEFORS Mikael|              Sweden|        null|
#       AGHAYEV Rafael|          Azerbaijan|        null|
# AU Hoi Shun Steph...|    Hong Kong, China|        null|
#         BOYER Marine|              France|        null|
#          CAIRNS Anne|               Samoa|        null|
#                 null|              Brazil|   Athletics|
#                 null|United States of ...|        Judo|
#        de BOD Stefan|        South Africa|        null|
#                 null|           Australia|    Football|
# +--------------------+--------------------+------------+
#
# </div>

# %%
for x in dfTeams.columns:
    if "_c" in x:
        dfTeams=dfTeams.drop(x)
dfTeams.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+--------------+--------------------+--------------------+
#          Name|    Discipline|                 NOC|               Event|
# +-------------+--------------+--------------------+--------------------+
#       Belgium|3x3 Basketball|             Belgium|                 Men|
#         China|3x3 Basketball|People&#39;s Republic...|                 Men|
#         China|3x3 Basketball|People&#39;s Republic...|               Women|
#        France|3x3 Basketball|              France|               Women|
#         Italy|3x3 Basketball|               Italy|               Women|
#         Japan|          null|               Japan|                 Men|
#         Japan|3x3 Basketball|               Japan|               Women|
#        Latvia|3x3 Basketball|              Latvia|                 Men|
#      Mongolia|3x3 Basketball|            Mongolia|               Women|
#   Netherlands|3x3 Basketball|         Netherlands|                 Men|
#        Poland|3x3 Basketball|              Poland|                 Men|
#           ROC|3x3 Basketball|                 ROC|                 Men|
#           ROC|3x3 Basketball|                 ROC|               Women|
#       Romania|3x3 Basketball|                null|               Women|
#        Serbia|3x3 Basketball|              Serbia|                 Men|
#     Lithuania|      Swimming|           Lithuania|Men&#39;s 4 x 100m Me...|
# United States|3x3 Basketball|United States of ...|               Women|
#     Australia|       Archery|           Australia|          Men&#39;s Team|
#     Australia|       Archery|           Australia|          Mixed Team|
#    Bangladesh|       Archery|          Bangladesh|          Mixed Team|
# +-------------+--------------+--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
dfnullteam=dfTeams.where(reduce(lambda x, y: x | y, (f.col(x).isNull() | (f.col(x)=="null") for x in dfTeams.columns)))
# Reduce-> implementing function across a sequence and in this case funct would be returning true if any of the value in the sequence is true which means atleast one of the column value is null
dfnullteam.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+--------------+--------------------+--------------------+
#          Name|    Discipline|                 NOC|               Event|
# +-------------+--------------+--------------------+--------------------+
#         Japan|          null|               Japan|                 Men|
#       Romania|3x3 Basketball|                null|               Women|
# United States|          null|United States of ...|          Men&#39;s Team|
#   Netherlands|     Athletics|                null|Women&#39;s 4 x 100m ...|
#       Nigeria|          null|             Nigeria|                 Men|
#           ROC|       Fencing|                 ROC|                null|
#         Japan|          null|               Japan|                null|
# +-------------+--------------+--------------------+--------------------+
#
# </div>

# %%
print("The percentage of null in Athlete is {}%".format((dfnullathlete.count()/dfAthletes.count())*100))
print("The percentage of null in Medals is {}%".format((dfnullmedal.count()/dfMedals.count())*100))
print("The percentage of null in Teams is {}%".format((dfnullteam.count()/dfTeams.count())*100))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The percentage of null in Athlete is 0.0990455609580407%
# The percentage of null in Medals is 11.458333333333332%
# The percentage of null in Teams is 0.9283819628647214%
# </div>

# %%
pip install fuzzywuzzy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: fuzzywuzzy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-424d3f47-9e00-4be8-b4c8-ded7139a6478/lib/python3.8/site-packages (0.18.0)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-424d3f47-9e00-4be8-b4c8-ded7139a6478/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# </div>

# %%
pip install python-Levenshtein
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: python-Levenshtein in /local_disk0/.ephemeral_nfs/envs/pythonEnv-424d3f47-9e00-4be8-b4c8-ded7139a6478/lib/python3.8/site-packages (0.12.2)
# Requirement already satisfied: setuptools in /databricks/python3/lib/python3.8/site-packages (from python-Levenshtein) (50.3.1)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-424d3f47-9e00-4be8-b4c8-ded7139a6478/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# </div>

# %%
from fuzzywuzzy import fuzz, process
fuzz.ratio("apain","Spain")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: 80</div>

# %%
pip install country_list
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: country_list in /local_disk0/.ephemeral_nfs/envs/pythonEnv-424d3f47-9e00-4be8-b4c8-ded7139a6478/lib/python3.8/site-packages (1.0.0)
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-424d3f47-9e00-4be8-b4c8-ded7139a6478/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# </div>

# %%
from country_list import countries_for_language
countries=countries_for_language('en')
print(countries)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;AF&#39;, &#39;Afghanistan&#39;), (&#39;AX&#39;, &#39;Åland Islands&#39;), (&#39;AL&#39;, &#39;Albania&#39;), (&#39;DZ&#39;, &#39;Algeria&#39;), (&#39;AS&#39;, &#39;American Samoa&#39;), (&#39;AD&#39;, &#39;Andorra&#39;), (&#39;AO&#39;, &#39;Angola&#39;), (&#39;AI&#39;, &#39;Anguilla&#39;), (&#39;AQ&#
span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;dfAthletes&#39; is not defined</div>

# %%
dfMedalsNew=dfMedals.subtract(dfnullmedal)#give union of all error data inside subtract
dfMedalsNew.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3855486133687773&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>dfMedalsNew<span class="ansi-blue-fg">=</span>dfMedals<span class="ansi-blue-fg">.</span>subtract<span class="ansi-blue-fg">(</span>dfnullmedal<span class="ansi-blue-fg">)</span><span class="ansi-red-fg">#give union of all error data inside subtract</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> dfMedalsNew<span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;dfMedals&#39; is not defined</div>

# %%
dfTeamsNew=dfTeams.subtract(dfnullteam)#give union of all error data inside subtract
dfTeamsNew.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3855486133687775&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>dfTeamsNew<span class="ansi-blue-fg">=</span>dfTeams<span class="ansi-blue-fg">.</span>subtract<span class="ansi-blue-fg">(</span>dfnullteam<span class="ansi-blue-fg">)</span><span class="ansi-red-fg">#give union of all error data inside subtract</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> dfTeamsNew<span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;dfTeams&#39; is not defined</div>

# %%
emptyRDD = spark.sparkContext.emptyRDD()
from pyspark.sql.types import StructType,StructField, StringType, FloatType
schema = StructType([
  StructField('TableName', StringType(), True),
  StructField('Column', StringType(), True),
  StructField('CheckType', StringType(), True)
  ])
dfError=spark.createDataFrame(emptyRDD,schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
nullschema=StructType([
    StructField('TableName',StringType(),True),
    StructField('NullErrorPercentage',FloatType(),True)
])
dfNullErrorPer=spark.createDataFrame([('Athletes',round(dfnullathlete.count()/dfAthletes.count()*100,3)),('Medals',round(dfnullmedal.count()/dfMedals.count()*100,3)),('Teams',round(dfnullteam.count()/dfTeams.count()*100,3))],nullschema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3855486133687780&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>     StructField<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;NullErrorPercentage&#39;</span><span class="ansi-blue-fg">,</span>FloatType<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span><span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> ])
# <span class="ansi-green-fg">----&gt; 5</span><span class="ansi-red-fg"> </span>dfNullErrorPer<span class="ansi-blue-fg">=</span>spark<span class="ansi-blue-fg">.</span>createDataFrame<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;Athletes&#39;</span><span class="ansi-blue-fg">,</span>round<span class="ansi-blue-fg">(</span>dfnullathlete<span class="ansi-blue-fg">.</span>count<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">/</span>dfAthletes<span class="ansi-blue-fg">.</span>count<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">*</span><span class="ansi-cyan-fg">100</span><span class="ansi-blue-fg">,</span><span class="ansi-cyan-fg">3</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;Medals&#39;</span><span class="ansi-blue-fg">,</span>round<span class="ansi-blue-fg">(</span>dfnullmedal<span class="ansi-blue-fg">.</span>count<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">/</span>dfMedals<span class="ansi-blue-fg">.</span>count<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">*</span><span class="ansi-cyan-fg">100</span><span class="ansi-blue-fg">,</span><span class="ansi-cyan-fg">3</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;Teams&#39;</span><span class="ansi-blue-fg">,</span>round<span class="ansi-blue-fg">(</span>dfnullteam<span class="ansi-blue-fg">.</span>count<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">/</span>dfTeams<span class="ansi-blue-fg">.</span>count<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">*</span><span class="ansi-cyan-fg">100</span><span class="ansi-blue-fg">,</span><span class="ansi-cyan-fg">3</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span>nullschema<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;dfnullathlete&#39; is not defined</div>

# %%
dfNullErrorPer.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3855486133687786&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>dfNullErrorPer<span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;dfNullErrorPer&#39; is not defined</div>

# %%
try:
    dfAthletesDistinct = dfAthletes.distinct() #Distinct Records of Athlete Table
except Exception as e:
    print(e)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Finding duplicate records for Athlete Table
import pyspark.sql.functions as f

try:
    dfAthletesDupIndicator = dfAthletes.join(dfAthletes.groupBy(dfAthletes.columns).agg((f.count("*")>1).cast("int").alias("Duplicate_indicator")), on=dfAthletes.columns, how="inner")
except Exception as e:
    print(e)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
try:
    dfAthletesDuplicate = dfAthletesDupIndicator.filter("Duplicate_indicator > 0").distinct().drop("Duplicate_indicator") #Duplicate Records of Athlete Table
except Exception as e:
    print(e)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfAthletesDuplicate.write.csv("abfss://capstonedata@capstonebrillio.dfs.core.windows.net/AthleteDuplicate")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfMedalsDistinct = dfMedals.distinct() #Distinct records of Medals Table
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Finding duplicate records for Medals Table
import pyspark.sql.functions as f
dfMedalsDupIndicator = dfMedals.join(
    dfMedals.groupBy(dfMedals.columns).agg((f.count("*")>1).cast("int").alias("Duplicate_indicator")),
    on=dfMedals.columns,
    how="inner"
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfMedalsDuplicate = dfMedalsDupIndicator.filter("Duplicate_indicator > 0").distinct().drop("Duplicate_indicator") #Duplicate Records of Medals Table
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfMedalsDuplicate.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-531740957582573&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>dfMedalsDuplicate<span class="ansi-blue-fg">.</span>show<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;dfMedalsDuplicate&#39; is not defined</div>

# %%
dfMedalsDuplicate.write.csv("abfss://capstonedata@capstonebrillio.dfs.core.windows.net/MedalsDuplicate")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfTeamsDistinct = dfTeams.distinct() #Distinct records of Teams Table
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Finding duplicate records for Teams Table
import pyspark.sql.functions as f
dfTeamsDupIndicator = dfTeams.join(
    dfTeams.groupBy(dfTeams.columns).agg((f.count("*")>1).cast("int").alias("Duplicate_indicator")),
    on=dfTeams.columns,
    how="inner"
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfTeamsDuplicate = dfTeamsDupIndicator.filter("Duplicate_indicator > 0").distinct().drop("Duplicate_indicator") #Duplicate Records of Medals Table
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfTeamsDuplicate.write.csv("abfss://capstonedata@capstonebrillio.dfs.core.windows.net/TeamsDuplicate")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from functools import reduce
dfAthleteAlnum=dfAthlete.select(reduce(lambda x, y: x | y, (f.col(x).cast("int").isNotNull() for x in dfAthlete.columns)).alias("al"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.functions import monotonically_increasing_id
dfa=dfAthlete.withColumn("rowId", monotonically_increasing_id())
dfb=dfAthleteAlnum.withColumn("rowId", monotonically_increasing_id())

dfAthleteValidity=dfa.join(dfb,("rowId")).drop("rowId")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
import pyspark.sql.functions as f
dfAthletesValidity = dfAthletesValidity.filter(f.col("check") ==True).drop("check")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
dfMedalsAlnum=dfMedalsTrim.select("Team/NOC", f.col("Team/NOC").cast("int").isNotNull().alias("check"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.functions import monotonically_increasing_id
dfa=dfMedals.withColumn("rowId", monotonically_increasing_id())
dfb=dfMedalsAlnum.withColumn("rowId", monotonically_increasing_id())

dfMedalsValidity=dfa.join(dfb,("rowId")).drop("rowId")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
import pyspark.sql.functions as f
dfMedalsValidity = dfMedalsValidity.filter(f.col("check") ==True).drop("check")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
dfMedalsValidity.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
dfTeamsAlnum=dfTeamsTrim.select(reduce(lambda x, y: x | y, (f.col(x).cast("int").isNotNull() for x in dfAthlete.columns)).alias("alnum"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.functions import monotonically_increasing_id
dfa=dfTeams.withColumn("rowId", monotonically_increasing_id())
dfb=dfTeamsAlnum.withColumn("rowId", monotonically_increasing_id())

dfTeamsValidity=dfa.join(dfb,("rowId")).drop("rowId")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
import pyspark.sql.functions as f
dfTeamsValidity = dfTeamsValidity.filter(f.col("alnum") ==True).drop("alnum")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
dfTeamsValidity.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
